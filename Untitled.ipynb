# %%
import pandas as pd
import numpy as np

# %%
import re

# %%
cd
# Out:
# C:\Users\user

# %%
ptype.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-385f7b849371> in <module>()
# ----> 1 ptype.columns
#
# NameError: name 'ptype' is not defined

# %%
ptype = pd.read_csv('book3.csv')

# %%
# abc=re.compile(r'.+(Buy).+get',re.I)

# %%
# if abc.search(ptype["PROMOTION_DESCRIPTION"]):
#    ptype["type"]="Quantity Discount";

# %%
ptype['PROMOTION_DESCRIPTION']
# Out:
# 0                              Buy 3 Cookies Get 1 Free
# 1                                  15% Off Any One Item
# 2                                  20% Off Any One Item
# 3     $2 Off Any 1 Grande or Venti Handcrafted Espre...
# 4                   Buy 1 Fresh Baked Cookie Get 1 Free
# 5                              20% Off Any One Cookbook
# 6                               20% Off Any One Mystery
# 7                                20% Off 1 Picture Book
# 8     Black Friday Complimentary Tall Handcrafted Be...
# 9                                  25% Off Any One Item
# 10                  $2 Cheesecake Factory Bakery Slices
# 11                      30% Off One Moleskine Item Item
# 12                          $1 Off Any Item in Bakecase
# 13                $1 Any Handcrafted Beverage After 2pm
# 14                    $1 Off VENTI® Starbucks® Beverage
# 15           $1 Off any Starbucks® Handcrafted Beverage
# 16                                 30% Off Any One Item
# ...

# %%
# ptype['disc_Type']

# %%
re.match(r'\$\d+',ptype['PROMOTION_DESCRIPTION'][3], re.I)
# Out:
# <_sre.SRE_Match object; span=(0, 2), match='$2'>

# %%
for index,row in ptype.iterrows():
    search_text =  row['PROMOTION_DESCRIPTION']
#   print(search_text)
    if re.search(r'\$', search_text):
#       print(True)
        ptype.loc[index,'disc_Type'] = 'PricePromotion'
#       print("row:",row['disc_Type'])

# %%
for index,row in ptype.iterrows():
    search_text =  row['PROMOTION_DESCRIPTION']
#    print(search_text)
    if re.search(r'%', search_text):
#        print(True)
        ptype.loc[index,'disc_Type'] = 'Discount'
#        print("row:",row['disc_Type'])

# %%
# ptype['disc_Type']

# %%
ptype['disc_Type'].value_counts()
# Out:
# Discount             20
# PricePromotion       12
# Quantity_Discount     3
# Bundle                2
# Name: disc_Type, dtype: int64

# %%
temp = open('events.txt','r').read().split('\n')
print(temp)w
# Out:
# ['Blue Monday', "Valentine's Day", 'London Fashion Week', "Mother's Day", 'Easter Weekend', 'Wedding season', "Father's Day", 'Festival season', 'E-commerce Expo', 'Buy British Day', 'Halloween', 'Black Friday', 'Cyber Monday', 'Small Business Saturday', 'Free Shipping Day', 'Christmas', 'Boxing Day Sales', 'Educator Appreciation Week', 'Educator Appreciation day', "Veteran's day", 'veteran', 'Tax Day']

# %%
temp
# Out:
# ['Blue Monday',
#  "Valentine's Day",
#  'London Fashion Week',
#  "Mother's Day",
#  'Easter Weekend',
#  'Wedding season',
#  "Father's Day",
#  'Festival season',
#  'E-commerce Expo',
#  'Buy British Day',
#  'Halloween',
#  'Black Friday',
#  'Cyber Monday',
#  'Small Business Saturday',
#  'Free Shipping Day',
#  'Christmas',
#  'Boxing Day Sales',
#  'Educator Appreciation Week',
#  'Educator Appreciation day',
#  "Veteran's day",
#  'veteran',
#  'Tax Day']

# %%
ptype.head()
# Out:
#                                PROMOTION_DESCRIPTION       disc_Type
# 0                           Buy 3 Cookies Get 1 Free             NaN
# 1                               15% Off Any One Item        Discount
# 2                               20% Off Any One Item        Discount
# 3  $2 Off Any 1 Grande or Venti Handcrafted Espre...  PricePromotion
# 4                Buy 1 Fresh Baked Cookie Get 1 Free             NaN

# %%
for index,row in ptype.iterrows():
    search_text =  row['PROMOTION_DESCRIPTION']
    for i in temp:
        if re.search(i, search_text, re.I):
            ptype.loc[index,'disc_Type'] = 'Bundle'
ptype.disc_Type.unique()
# Out:
# array([nan, 'Discount', 'PricePromotion', 'Bundle'], dtype=object)

# %%
for index,row in ptype.iterrows():
    search_text =  row['PROMOTION_DESCRIPTION']
#    print(search_text)
    if re.search(r'(buy).+(get)', search_text, re.I):
#        print(True)
        ptype.loc[index,'disc_Type'] = 'Quantity_Discount'
#       print("row:",row['disc_Type'])

# %%
ptype.to_csv("ptype2.csv")

# %%
ptype['disc_Type'].value_counts()
# Out:
# Discount             18
# PricePromotion       12
# Quantity_Discount     5
# Bundle                2
# Name: disc_Type, dtype: int64

# %%
ptype['disc_Type']
# Out:
# 0     Quantity_Discount
# 1              Discount
# 2              Discount
# 3        PricePromotion
# 4     Quantity_Discount
# 5              Discount
# 6              Discount
# 7              Discount
# 8                   NaN
# 9              Discount
# 10       PricePromotion
# 11             Discount
# 12       PricePromotion
# 13       PricePromotion
# 14       PricePromotion
# 15       PricePromotion
# 16             Discount
# 17    Quantity_Discount
# 18    Quantity_Discount
# 19             Discount
# 20       PricePromotion
# 21             Discount
# 22             Discount
# 23                  NaN
# 24             Discount
# 25       PricePromotion
# 26       PricePromotion
# 27       PricePromotion
# 28             Discount
# 29    Quantity_Discount
# 30             Discount
# 31       PricePromotion
# 32             Discount
# 33                  NaN
# 34       PricePromotion
# 35             Discount
# 36                  NaN
# 37             Discount
# ...

# %%
from spacy.matcher import PhraseMatcher
import spacy

# %%
nlp = spacy.load('en')

# %%
ner = EntityRecognizer(nlp.vocab)
spacy_text = nlp(u'buy three cookies get 1 free')
# for token in spacy_text
print(ner(spacy_text))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-805a0c18bb20> in <module>()
#       2 spacy_text = nlp(u'buy three cookies get 1 free')
#       3 # for token in spacy_text
# ----> 4 print(ner(spacy_text))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.get_batch_model()
#
# TypeError: 'bool' object is not iterable

# %%
from spacy.pipeline import  EntityRecognizer
for index,row in ptype.iterrows():
    search_text = (row['PROMOTION_DESCRIPTION'])
#     print(type(search_text))
#     ner = EntityRecognizer(nlp.vocab)
#     print(search_text)
    imp_test = nlp(search_text)
    print("sentence:",imp_test)
    for entity in imp_test.ents:
        print(entity.text,entity.label_)
#  processed = ner(imp_test)
#    print("here,processed")
#     for token in imp_test:
 # print(token.text,token.ner_)
    #print(imp_test,imp_test.ents)
# Out:
# sentence: Buy 3 Cookies Get 1 Free
# sentence: 15% Off Any One Item
# 15% PERCENT
# Any One Item ORG
# sentence: 20% Off Any One Item
# 20% PERCENT
# Any One Item ORG
# sentence: $2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage
# 2 MONEY
# Any 1 Grande ORG
# Venti Handcrafted Espresso PERSON
# sentence: Buy 1 Fresh Baked Cookie Get 1 Free
# sentence: 20% Off Any One Cookbook
# 20% PERCENT
# sentence: 20% Off Any One Mystery
# 20% PERCENT
# sentence: 20% Off 1 Picture Book
# 20% Off PERCENT
# sentence: Black Friday Complimentary Tall Handcrafted Beverage
# sentence: 25% Off Any One Item
# 25% PERCENT
# Any One Item ORG
# sentence: $2 Cheesecake Factory Bakery Slices
# 2 Cheesecake Factory Bakery ORG
# sentence: 30% Off One Moleskine Item Item
# 30% Off PERCENT
# One CARDINAL
# Moleskine Item Item ORG
# sentence: $1 Off Any Item in Bakecase
# sentence: $1 Any Handcrafted Beverage After 2pm
# 1 MONEY
# 2pm TIME
# sentence: $1 Off VENTI® Starbucks® Beverage
# ...

# %%
from spacy.pipeline import  EntityRecognizer
imp_test = nlp("Jingle Bells Christmas Carol Coloring Only $5 with the purchase of Any Coloring Book")
print("sentence:",imp_test)
for entity in imp_test.ents:
    print(entity.text,entity.label_)
#  processed = ner(imp_test)
#    print("here,processed")
#     for token in imp_test:
 # print(token.text,token.ner_)
    #print(imp_test,imp_test.ents)
# Out:
# sentence: Jingle Bells Christmas Carol Coloring Only $5 with the purchase of Any Coloring Book
# Jingle Bells PERSON
# Carol Coloring PERSON
# 5 MONEY
# Any Coloring Book WORK_OF_ART

# %%
from spacy.pipeline import  EntityRecognizer
for index,row in ptype.iterrows():
    search_text = (row['PROMOTION_DESCRIPTION'])
#     print(type(search_text))
#     ner = EntityRecognizer(nlp.vocab)
#     print(search_text)
    imp_test = nlp(search_text)
#     print("sentence:",imp_test)
#     for entity in imp_test.ents:
#         print(entity,entity.label_)
#  processed = ner(imp_test)
#    print("here,processed")
#     for token in imp_test:
 # print(token.text,token.ner_)
    #print(imp_test,imp_test.ents)
    for token in imp_test:
        print ('"' + token.text + '"')
# Out:
# "Buy"
# "3"
# "Cookies"
# "Get"
# "1"
# "Free"
# "15"
# "%"
# "Off"
# "Any"
# "One"
# "Item"
# "20"
# "%"
# "Off"
# "Any"
# "One"
# "Item"
# "$"
# "2"
# "Off"
# "Any"
# "1"
# "Grande"
# "or"
# "Venti"
# "Handcrafted"
# "Espresso"
# "or"
# "Blended"
# "Beverage"
# "Buy"
# "1"
# "Fresh"
# "Baked"
# "Cookie"
# "Get"
# "1"
# "Free"
# "20"
# "%"
# "Off"
# "Any"
# "One"
# "Cookbook"
# "20"
# "%"
# "Off"
# "Any"
# "One"
# "Mystery"
# "20"
# "%"
# "Off"
# "1"
# "Picture"
# "Book"
# "Black"
# "Friday"
# "Complimentary"
# "Tall"
# "Handcrafted"
# "Beverage"
# "25"
# "%"
# "Off"
# "Any"
# "One"
# "Item"
# "$"
# "2"
# "Cheesecake"
# "Factory"
# "Bakery"
# "Slices"
# "30"
# "%"
# "Off"
# "One"
# "Moleskine"
# "Item"
# "Item"
# "$"
# "1"
# "Off"
# "Any"
# "Item"
# "in"
# "Bakecase"
# "$"
# "1"
# "Any"
# "Handcrafted"
# "Beverage"
# "After"
# "2"
# "pm"
# "$"
# "1"
# "Off"
# "VENTI"
# "®"
# "Starbucks"
# "®"
# "Beverage"
# "$"
# "1"
# "Off"
# "any"
# "Starbucks"
# "®"
# "Handcrafted"
# "Beverage"
# ...

# %%
import os
os.getcwd()
os.chdir('C:\\Users\\user\\Desktop')
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop'

# %%
category = pd.read_csv('category.csv')
category.head()
len(category)
# Out:
# 163

# %%
category=category.drop_duplicates(subset=None, keep='first', inplace=False)
len(category)
# Out:
# 160

# %%
j=0
for string in ptype['PROMOTION_DESCRIPTION']:
    for ent in category['ENTITY']:
        reg_exp = reg_exp = """r'\\b(""" + ent + """)\\b'"""
        regex = re.compile(reg_exp, re.IGNORECASE)
        if(regex.search(string)):
            for i in re.finditer(reg_exp,string,re.I):
                print (i.start())
                print (string)

# %%
ent = "teen books"
reg_exp = """r''\\b(""" + ent + """)\\b'"""
print(reg_exp)
regex = re.compile(reg_exp, re.IGNORECASE)
st = "20% off on teen books"
if(regex.search(st)):
    print("yes")
# Out:
# r''\b(teen books)\b'

# %%
for string in ptype['PROMOTION_DESCRIPTION']:
    for ent in category['ENTITY']:        
        if(re.findall(r'\b' + ent + r'\b',string, re.I)):
            for i in re.finditer(ent,string,re.I):
                print ("('"+string+"', {'entities': [("+str(i.start())+", "+str(i.end())+", 'ITEM')]}),")
# Out:
# ('Buy 3 Cookies Get 1 Free', {'entities': [(6, 13, 'ITEM')]}),
# ('$2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage', {'entities': [(61, 69, 'ITEM')]}),
# ('$2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage', {'entities': [(53, 69, 'ITEM')]}),
# ('$2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage', {'entities': [(41, 49, 'ITEM')]}),
# ('$2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage', {'entities': [(29, 69, 'ITEM')]}),
# ('Buy 1 Fresh Baked Cookie Get 1 Free', {'entities': [(12, 24, 'ITEM')]}),
# ('20% Off Any One Cookbook', {'entities': [(16, 24, 'ITEM')]}),
# ('20% Off Any One Mystery', {'entities': [(16, 23, 'ITEM')]}),
# ('20% Off 1 Picture Book', {'entities': [(18, 22, 'ITEM')]}),
# ('20% Off 1 Picture Book', {'entities': [(10, 22, 'ITEM')]}),
# ('Black Friday Complimentary Tall Handcrafted Beverage', {'entities': [(32, 52, 'ITEM')]}),
# ...

# %%
# for string in ptype['PROMOTION_DESCRIPTION']:
#     for ent in category['ENTITY']:        
#         if(re.search(r'\b' + ent + r'\b',string, re.I)):
#             for i in re.finditer(ent,string,re.I):
#                 print ("'"+string+"', [("+str(i.start())+", "+str(i.end())+", 'ITEM')])")

# %%
from __future__ import unicode_literals, print_function

import plac
import random
from pathlib import Path
import spacy

# %%
# TRAIN_DATA=[('Buy 3 Cookies Get 1 Free', {'entities': [(6, 13, 'ITEM')]}),
# ('$2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage', {'entities': [(53, 69, 'ITEM')]}),
# ('$2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage', {'entities': [(41, 49, 'ITEM')]}),
# ('Buy 1 Fresh Baked Cookie Get 1 Free', {'entities': [(12, 24, 'ITEM')]}),
# ('20% Off Any One Cookbook', {'entities': [(16, 24, 'ITEM')]}),
# ('20% Off Any One Mystery', {'entities': [(16, 23, 'ITEM')]}),
# ('20% Off 1 Picture Book', {'entities': [(10, 22, 'ITEM')]}),
# ('Black Friday Complimentary Tall Handcrafted Beverage', {'entities': [(32, 52, 'ITEM')]}),
# ('$2 Cheesecake Factory Bakery Slices', {'entities': [(3, 35, 'ITEM')]}),
# ('$1 Off Any Item in Bakecase', {'entities': [(19, 27, 'ITEM')]}),
# ('$1 Any Handcrafted Beverage After 2pm', {'entities': [(7, 27, 'ITEM')]}),
# ('$1 Off VENTI® Starbucks® Beverage', {'entities': [(25, 33, 'ITEM')]}),
# ('$1 Off any Starbucks® Handcrafted Beverage', {'entities': [(22, 42, 'ITEM')]}),
# ('Buy one beverage, get a CroMuffin for 50% Off', {'entities': [(8, 16, 'ITEM')]}),
# ('Buy one beverage, get a CroMuffin for 50% Off', {'entities': [(24, 33, 'ITEM')]}),
# ('Harney Tea Tin - Buy One Get One Free Offer', {'entities': [(0, 14, 'ITEM')]}),
# ('20% Off One History Book (Trade, excludes Bargain)', {'entities': [(12, 24, 'ITEM')]}),
# ('$10 Off Godiva box purchase of $30 or more', {'entities': [(8, 18, 'ITEM')]}),
# ('Save Around Coupon Book - 15% Off any one item', {'entities': [(12, 23, 'ITEM')]}),
# ('KidStuff Coupon Booklet - 15% Off any one item', {'entities': [(0, 23, 'ITEM')]}),
# ('Half Off Any Frappuccino® During Happy Hour (3pm - 6pm)', {'entities': [(13, 24, 'ITEM')]}),
# ('$10 Off any Whole Cheesecake', {'entities': [(18, 28, 'ITEM')]}),
# ('30% Off Any Collectible Edition', {'entities': [(12, 31, 'ITEM')]}),
# ('Coloring Book Offer: Buy 1, Get 1 50% Off With Single-Use Coupon', {'entities': [(0, 13, 'ITEM')]}),
# ('20% Off Any One Teen Book', {'entities': [(16, 25, 'ITEM')]}),
# ('$1 Off Any Slice of Cheesecake', {'entities': [(11, 30, 'ITEM')]}),
# ('Black Friday Complimentary Tall Hot COffee', {'entities': [(36, 42, 'ITEM')]}),
# ('Any 1 Grande Beverage for $2', {'entities': [(13, 21, 'ITEM')]}),
# ('1 Free book-selected titles', {'entities': [(7, 27, 'ITEM')]}),
# ('30% Off the list price of one eligible picture book', {'entities': [(39, 51, 'ITEM')]}),
# ('30% Off the list price of one eligible cookbook', {'entities': [(39, 47, 'ITEM')]})]

# %%
## generating entities using regex and categories list
for string in test['Promotion_Description']:
    for ent in category['ENTITY']:        
        if(re.findall(r'\b' + ent + r'?\b',string, re.I)):
            for string in test['Promotion_Description']:
                for ent in category['ENTITY']:        
                    if(re.findall(r'\b' + ent + r'?\b',string, re.I)):
            
            for i in re.finditer(ent,string,re.I):
                print ("('"+string+"', {'entities': [("+str(i.start())+", "+str(i.end())+", 'ITEM')]}),")
# Out:
# ('"Bobby Flay's Barbecue Addiction" $14.99 Offer', {'entities': [(1, 32, 'ITEM')]}),
# ('10% Off littleBits STEAM set - In Store', {'entities': [(8, 28, 'ITEM')]}),
# ('30% Off Nook Accessories', {'entities': [(8, 24, 'ITEM')]}),
# ('NOOK GlowLight Plus Trade In', {'entities': [(0, 19, 'ITEM')]}),
# ('10% Off X-Wing set - In Store', {'entities': [(8, 18, 'ITEM')]}),
# ('Get a Godiva 4pc Gift Card Ballotin for $5 with a $25 or more Gift Card Purchase - In Store', {'entities': [(17, 26, 'ITEM')]}),
# ('Get a Godiva 4pc Gift Card Ballotin for $5 with a $25 or more Gift Card Purchase - In Store', {'entities': [(62, 71, 'ITEM')]}),
# ('Get a Godiva 4pc Gift Card Ballotin for $5 with a $25 or more Gift Card Purchase - In Store', {'entities': [(5, 35, 'ITEM')]}),
# ('$10 Off any Whole Cheesecake', {'entities': [(18, 28, 'ITEM')]}),
# ('$1 Off VENTIÂ® StarbucksÂ® Beverage', {'entities': [(27, 35, 'ITEM')]}),
# ('$5 Off One CD', {'entities': [(11, 13, 'ITEM')]}),
# ...

# %%
TRAIN_DATA=[('Buy 3 Cookies Get 1 Free', {'entities': [(6, 13, 'ITEM')]}),
('$2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage', {'entities': [(53, 69, 'ITEM'),(41, 49, 'ITEM')]}),
('Buy 1 Fresh Baked Cookie Get 1 Free', {'entities': [(12, 24, 'ITEM')]}),
('20% Off Any One Cookbook', {'entities': [(16, 24, 'ITEM')]}),
('20% Off Any One Mystery', {'entities': [(16, 23, 'ITEM')]}),
('20% Off 1 Picture Book', {'entities': [(10, 22, 'ITEM')]}),
('Black Friday Complimentary Tall Handcrafted Beverage', {'entities': [(32, 52, 'ITEM')]}),
('$2 Cheesecake Factory Bakery Slices', {'entities': [(3, 35, 'ITEM')]}),
('$1 Off Any Item in Bakecase', {'entities': [(19, 27, 'ITEM')]}),
('$1 Any Handcrafted Beverage After 2pm', {'entities': [(7, 27, 'ITEM')]}),
('$1 Off VENTI® Starbucks® Beverage', {'entities': [(25, 33, 'ITEM')]}),
('$1 Off any Starbucks® Handcrafted Beverage', {'entities': [(22, 42, 'ITEM')]}),
('Buy one beverage, get a CroMuffin for 50% Off', {'entities': [(8, 16, 'ITEM'), (24, 33, 'ITEM')]}),
('Harney Tea Tin - Buy One Get One Free Offer', {'entities': [(0, 14, 'ITEM')]}),
('20% Off One History Book (Trade, excludes Bargain)', {'entities': [(12, 24, 'ITEM')]}),
('$10 Off Godiva box purchase of $30 or more', {'entities': [(8, 18, 'ITEM')]}),
('Save Around Coupon Book - 15% Off any one item', {'entities': [(12, 23, 'ITEM')]}),
('KidStuff Coupon Booklet - 15% Off any one item', {'entities': [(0, 23, 'ITEM')]}),
('Half Off Any Frappuccino® During Happy Hour (3pm - 6pm)', {'entities': [(13, 24, 'ITEM')]}),
('$10 Off any Whole Cheesecake', {'entities': [(18, 28, 'ITEM')]}),
('30% Off Any Collectible Edition', {'entities': [(12, 31, 'ITEM')]}),
('Coloring Book Offer: Buy 1, Get 1 50% Off With Single-Use Coupon', {'entities': [(0, 13, 'ITEM')]}),
('20% Off Any One Teen Book', {'entities': [(16, 25, 'ITEM')]}),
('$1 Off Any Slice of Cheesecake', {'entities': [(11, 30, 'ITEM')]}),
('Black Friday Complimentary Tall Hot COffee', {'entities': [(36, 42, 'ITEM')]}),
('Any 1 Grande Beverage for $2', {'entities': [(13, 21, 'ITEM')]}),
('1 Free book-selected titles', {'entities': [(7, 27, 'ITEM')]}),
('30% Off the list price of one eligible picture book', {'entities': [(39, 51, 'ITEM')]}),
('30% Off the list price of one eligible cookbook', {'entities': [(39, 47, 'ITEM')]}),
('"Bobby Flay\'s Barbecue Addiction" $14.99 Offer', {'entities': [(1, 32, 'ITEM')]}),
('10% Off littleBits STEAM set - In Store', {'entities': [(8, 28, 'ITEM')]}),
('30% Off Nook Accessories', {'entities': [(8, 24, 'ITEM')]}),
('NOOK GlowLight Plus Trade In', {'entities': [(0, 19, 'ITEM')]}),
('10% Off X-Wing set - In Store', {'entities': [(8, 18, 'ITEM')]}),
('Get a Godiva 4pc Gift Card Ballotin for $5 with a $25 or more Gift Card Purchase - In Store', {'entities': [(5, 35, 'ITEM'), (62, 71, 'ITEM')]}),
('$10 Off any Whole Cheesecake', {'entities': [(18, 28, 'ITEM')]}),
('$1 Off VENTIÂ® StarbucksÂ® Beverage', {'entities': [(27, 35, 'ITEM')]}),
('$5 Off One CD', {'entities': [(11, 13, 'ITEM')]}),
('$1 Off VENTIÂ® StarbucksÂ® Beverage', {'entities': [(27, 35, 'ITEM')]}),
('Free Sleeve with Purchase of Samsung Galaxy Tab 4 NOOK 7"', {'entities': [(5, 11, 'ITEM'), (29, 57, 'ITEM')]}),
('Free Sleeve with Purchase of Samsung Galaxy Tab S2 NOOK 8"', {'entities': [(5, 11, 'ITEM'), (29, 58, 'ITEM')]}),
('Free Sleeve with Purchase of Samsung Galaxy Tab S2 NOOK 9"', {'entities': [(5, 11, 'ITEM'), (29, 58, 'ITEM')]}),
('Samsung Galaxy Tab A NOOK $99.99 Upgrader Offer', {'entities': [(0, 25, 'ITEM')]}),
('$8 Off One DVD or Blu-ray', {'entities': [(11, 25, 'ITEM')]}),
('Free Tall CaffÃ© Latte with Any CafÃ© Purchase (Store)', {'entities': [(5, 22, 'ITEM'), (32, 37, 'ITEM')]}),
('20% Off 1 Manga Title', {'entities': [(10, 21, 'ITEM')]}),
('$50 Credit Towards Purchase of Any Samsung Device', {'entities': [(35, 49, 'ITEM')]}),
('FREE NOOK Color Cable with purchase of Belkin Micro USB Cable', {'entities': [(5, 21, 'ITEM'), (39, 61, 'ITEM')]}),
('50% Off the Belkin Micro USB Charger in Black', {'entities': [(12, 36, 'ITEM')]}),
('Free Tall CaffÃ© Latte with Any CafÃ© Purchase (Store)', {'entities': [(5, 22, 'ITEM'), (32, 37, 'ITEM')]}),
('$8 Off One DVD or Blu-ray', {'entities': [(11, 25, 'ITEM')]}),
('$5 Off One CD (price- $15+)', {'entities': [(11, 13, 'ITEM')]}),
('Buy one beverage, get a CroMuffin for 50% Off', {'entities': [(8, 16, 'ITEM'), (24, 33, 'ITEM')]}),
('Samsung Galaxy Tab A NOOK $99.99 Upgrader Member Offer', {'entities': [(0, 25, 'ITEM')]}),
('1 Free Iced Tea (Any Size) for Members', {'entities': [(7, 15, 'ITEM')]}),
('$1 Off Any Pumpkin Item', {'entities': [(11, 18, 'ITEM')]}),
('$10 Off any Whole Cheesecake', {'entities': [(18, 28, 'ITEM')]}),
('$5 Off One CD', {'entities': [(11, 13, 'ITEM')]}),
('Free Tall CaffÃ© Latte with Any CafÃ© Purchase (Store)', {'entities': [(5, 22, 'ITEM'), (32, 37, 'ITEM')]}),
('$8 Off One DVD or Blu-ray', {'entities': [(11, 25, 'ITEM')]}),
('Samsung Galaxy Tab A NOOK $99.99 Upgrader Offer', {'entities': [(0, 25, 'ITEM')]}),
('Harney Tea Tin - Buy One Get One Free Offer', {'entities': [(0, 14, 'ITEM')]}),
('$10 Off Godiva box purchase of $30 or more', {'entities': [(8, 18, 'ITEM')]}),
('Buy 1 Get 1 Free - Godiva G Bar Collection', {'entities': [(19, 42, 'ITEM')]}),
('Save $50 When You Buy a Teac Turntable and Teac Speakers', {'entities': [(24, 56, 'ITEM')]}),
('$10 Off any Whole Cheesecake', {'entities': [(18, 28, 'ITEM')]}),
('Buy 2 Get 3rd Free on Starbucks 1lb COffee', {'entities': [(22, 42, 'ITEM')]}),
('Black Friday Complimentary Tall Hot COffee', {'entities': [(32, 42, 'ITEM')]}),
('Free Hot COffee for all Veterans', {'entities': [(5, 15, 'ITEM')]}),
('Free Tall CaffÃ© Latte with Any CafÃ© Purchase (Store)', {'entities': [(5, 22, 'ITEM'), (32, 37, 'ITEM')]}),
('$8 Off One DVD or Blu-ray', {'entities': [(11, 25, 'ITEM')]}),
('$5 Off One CD', {'entities': [(11, 13, 'ITEM')]}),
('Perfect for Little Ones Buy 2 Get the 3rd Free', {'entities': [(0, 23, 'ITEM')]}),
('Get Good Housekeeping cookbook for $9.99 with the purchase of any item in the store', {'entities': [(9, 30, 'ITEM')]}),
('40% Off GODIVA Seasonal Truffle Tin', {'entities': [(8, 35, 'ITEM')]}),
('Get Barnsie for only $9.95 when you buy any item', {'entities': [(4, 11, 'ITEM')]}),
('Get a $10 Gift Card with the Purchase of a Samsung Galaxy Tab A NOOK', {'entities': [(10, 19, 'ITEM'), (43, 68, 'ITEM')]}),
('20% Off One Harry & David Spring Item', {'entities': [(12, 37, 'ITEM')]}),
('Free Tall CaffÃ© Latte with Any CafÃ© Purchase (Store)', {'entities': [(5, 22, 'ITEM'), (32, 37, 'ITEM')]}),
('$5 Off Any DVD or Blu-ray Over $9.99', {'entities': [(11, 25, 'ITEM')]}),
('$5 Off One Vinyl LP', {'entities': [(11, 19, 'ITEM')]}),
('$5 Off Any DVD or Blu-ray Over $9.99', {'entities': [(11, 25, 'ITEM')]}),
('NOOK Samsung Upgrader Offer - Store', {'entities': [(0, 12, 'ITEM')]}),
('1 Free book-selected titles', {'entities': [(7, 27, 'ITEM')]}),
('20% Off (1) item $30 or more from GODIVAÂ®', {'entities': [(34, 42, 'ITEM')]}),
('$1 Off any StarbucksÂ® Handcrafted Beverage', {'entities': [(23, 43, 'ITEM')]}),
('Free Tall CaffÃ© Latte with Any CafÃ© Purchase (Store)', {'entities': [(5, 22, 'ITEM'), (32, 37, 'ITEM')]}),
('$5 Off Any DVD or Blu-ray Over $9.99', {'entities': [(11, 25, 'ITEM')]}),
('KidStuff Coupon Booklet - 15% Off any one item', {'entities': [(0, 23, 'ITEM')]}),
('Save Around Coupon Book - 15% Off any one item', {'entities': [(12, 23, 'ITEM')]}),
('Get a Godiva 4pc Gift Card Ballotin for $5 with a $25 or more Gift Card Purchase - In Store', {'entities': [(5, 35, 'ITEM'), (62, 71, 'ITEM')]}),
('$10 Off any Whole Cheesecake', {'entities': [(18, 28, 'ITEM')]}),
('Free Tall CaffÃ© Latte with Any CafÃ© Purchase (Store)', {'entities': [(5, 22, 'ITEM'), (32, 37, 'ITEM')]}),
('$5 Off Any DVD or Blu-ray Over $9.99', {'entities': [(11, 25, 'ITEM')]}),
('$15 Off Any Turntable', {'entities': [(12, 21, 'ITEM')]}),
('$1 Off 1 NakedÂ® Mighty MangoÂ®', {'entities': [(9, 31, 'ITEM')]}),
('$15 Off Any Turntable', {'entities': [(12, 21, 'ITEM')]}),
('$5 Off Any DVD or Blu-ray Over $9.99', {'entities': [(11, 25, 'ITEM')]}),
('$5 Off One Vinyl LP', {'entities': [(11, 19, 'ITEM')]}),
('Free Tall CaffÃ© Latte with Any CafÃ© Purchase (Store)', {'entities': [(5, 22, 'ITEM'), (32, 37, 'ITEM')]}),
('$1 Off Any Slice of Cheesecake', {'entities': [(11, 30, 'ITEM')]}),
('Any 1 Grande Beverage for $2', {'entities': [(13, 21, 'ITEM')]}),
('Buy 1 Fresh Baked Cookie Get 1 Free', {'entities': [(12, 24, 'ITEM')]}),
('Any 1 Grande Sized Handcrafted Beverage for $2', {'entities': [(19, 39, 'ITEM')]}),
('Buy 3 Cookies Get 1 Free', {'entities': [(6, 13, 'ITEM')]}),
('$2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage', {'entities': [(29, 69, 'ITEM')]}),
('Buy 1 Fresh Baked Cookie Get 1 Free', {'entities': [(12, 24, 'ITEM')]}),
('One Free Select Kids Beverage', {'entities': [(16, 29, 'ITEM')]}),
('$2 Off Any 1 Grande or Venti Handcrafted Espresso or Blended Beverage', {'entities': [(29, 69, 'ITEM')]}),
('20% Off Newsstand Purchase', {'entities': [(8, 17, 'ITEM')]}),
('$10 Off Godiva box purchase of $30 or more', {'entities': [(8, 18, 'ITEM')]}),
('Harney Tea Tin - Buy One Get One Free Offer', {'entities': [(0, 14, 'ITEM')]}),
('$5 Soup and Sandwich Combo (12pm-Close)', {'entities': [(3, 7, 'ITEM'), (12, 20, 'ITEM')]}),
('Black Friday Complimentary Tall Handcrafted Beverage', {'entities': [(32, 52, 'ITEM')]}),
('Free Beverage with CafÃ© Purchase', {'entities': [(5, 13, 'ITEM'), (19, 24, 'ITEM')]}),
('$2 Cheesecake Factory Bakery Slices', {'entities': [(3, 35, 'ITEM')]}),
('$1 Off Bakery Item', {'entities': [(7, 13, 'ITEM')]}),
('$10 Off Godiva box purchase of $25 or more', {'entities': [(8, 18, 'ITEM')]}),
('40% Off NOOK Tablet 7"', {'entities': [(8, 22, 'ITEM')]}),
('$10 Off any Whole Cheesecake', {'entities': [(18, 28, 'ITEM')]}),
('$10 Gift Card When You Spend $50', {'entities': [(4, 13, 'ITEM')]}),
('$25 Gift Card When You Spend $100', {'entities': [(4, 13, 'ITEM')]}),
('$5 Off Dylan\'s Candy Purchase of $10 or More', {'entities': [(7, 20, 'ITEM')]}),
('$1 Any Handcrafted Beverage After 2pm', {'entities': [(7, 27, 'ITEM')]}),
('$1 Off Any Item in Bakecase', {'entities': [(19, 27, 'ITEM')]}),
('$5 Off any Whole Cheesecake (Retail Me Not)', {'entities': [(17, 27, 'ITEM')]}),
('Buy a Copy of Consumer Reports and Get a Free Large COffee', {'entities': [(52, 58, 'ITEM')]}),
('Buy 1 Fresh Baked Cookie Get 1 Free', {'entities': [(12, 24, 'ITEM')]}),
('Educator Appreciation Days - $30 Off Cue Robot', {'entities': [(37, 46, 'ITEM')]}),
('$1 Off Bakery Item or Hot Coffee', {'entities': [(7, 13, 'ITEM'), (22, 32, 'ITEM')]}),
('$1 Off Any Pretzel', {'entities': [(11, 18, 'ITEM')]}),
('$1 Off Any 1 Grande or Venti Size Espresso or Blended Beverage', {'entities': [(34, 42, 'ITEM'), (46, 62, 'ITEM')]}),
('$2 Off Any Retail COffee', {'entities': [(18, 24, 'ITEM')]}),
('20% Off One Harry & David Item', {'entities': [(12, 25, 'ITEM')]}),
('Take 20% Off $125 or More RMN mobile', {'entities': [(26, 36, 'ITEM')]}),
('Get $10 Off $100 or more including new and used textbooks', {'entities': [(43, 57, 'ITEM')]}),
('Toddler Essentials - Buy 2, Get the 3rd Free', {'entities': [(0, 18, 'ITEM')]}),
('Buy 3 select paperbacks for $30', {'entities': [(13, 23, 'ITEM')]}),
('Buy 1, Get 1 50% Off - Study Aids & Test Prep', {'entities': [(23, 45, 'ITEM')]}),
('Save $5 on 2 Select Professional Books', {'entities': [(20, 38, 'ITEM')]}),
('Get "Bobby Flay\'s Barbecue Addiction" for only $14.99 with the purchase of any item', {'entities': [(5, 36, 'ITEM')]}),
('Extemely Cute Animals Operating Heavy Machinery Only $7.99 with the Purchase of Any Kids Book', {'entities': [(0, 47, 'ITEM'), (84, 93, 'ITEM')]}),
('Save $5 on 2 Select Young Readers Books', {'entities': [(20, 39, 'ITEM')]}),
('Nook Books - Buy 1, Get 1 50% Off', {'entities': [(0, 10, 'ITEM')]}),
('Nook Books - Buy 2, Get the 3rd Free', {'entities': [(0, 10, 'ITEM')]}),
('30% Off Nook Accessories', {'entities': [(8, 24, 'ITEM')]}),
('Free Shipping on New Textbooks', {'entities': [(21, 30, 'ITEM')]}),
('B&N Classics - Buy 2, Get the 3rd Free', {'entities': [(0, 12, 'ITEM')]}),
('Select Hardcovers - 2 for $30', {'entities': [(7, 17, 'ITEM')]}),
('$8 Off One DVD or Blu-ray (price $40+)', {'entities': [(11, 25, 'ITEM')]}),
('$10 Off One Home & Gift Item', {'entities': [(12, 23, 'ITEM')]}),
('Board Books - Buy 2, Get the 3rd Free', {'entities': [(0, 11, 'ITEM')]}),
('$5 Off One CD', {'entities': [(11, 13, 'ITEM')]}),
('$5 Off One Toy or Game Item (price $20+)', {'entities': [(11, 22, 'ITEM')]}),
('Save $5 on 2 Select Young Readers Books', {'entities': [(20, 39, 'ITEM')]}),
('Summer Reading - Save $5 on 2 Select Hardcovers', {'entities': [(37, 47, 'ITEM')]}),
('20% Off One Manga Title', {'entities': [(12, 23, 'ITEM')]}),
('DC Graphic Novels - Buy 2, Get the 3rd Free', {'entities': [(0, 17, 'ITEM')]}),
('Manga Mania Sale - Buy 2, Get the 3rd Free', {'entities': [(0, 12, 'ITEM')]}),
('Marvel Graphic Novels - Buy 2, Get the 3rd Free', {'entities': [(0, 21, 'ITEM')]}),
('Must Read Paperbacks - Buy 2, Get the 3rd Free', {'entities': [(10, 20, 'ITEM')]}),
('Select Board Books - 2 for $10', {'entities': [(7, 18, 'ITEM')]}),
('Are We There Yet Only $7.99 with the Purchase of Any Kids Book', {'entities': [(0, 16, 'ITEM'), (53, 62, 'ITEM')]}),
('Select Young Readers Books - 2 for $20', {'entities': [(7, 26, 'ITEM')]}),
('Free Express Shipping on New Textbooks', {'entities': [(29, 38, 'ITEM')]}),
('$8 Off One DVD or Blu-ray (price $40+)', {'entities': [(11, 25, 'ITEM')]}),
('$5 Off One Toy or Game Item (price $20+)', {'entities': [(11, 22, 'ITEM')]}),
('$10 Off One Home & Gift Item', {'entities': [(12, 23, 'ITEM')]}),
('$5 Off One CD', {'entities': [(11, 13, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('If You Ever Want to Bring an Alligator to School, Don\'t! Only $7.99 with the Purchase of Any Kids\' Book', {'entities': [(0, 56, 'ITEM'), (93, 103, 'ITEM')]}),
('Get 50% Off a Select Coloring Book with the Purchase of "Magical Jungle"', {'entities': [(21, 34, 'ITEM'), (57, 71, 'ITEM')]}),
('Select Hardcovers - 2 for $30', {'entities': [(7, 17, 'ITEM')]}),
('Select Business Books - Buy 1, Get 1 at 50% Off', {'entities': [(7, 21, 'ITEM')]}),
('How to Win Friends and Influence People $8.99 Offer', {'entities': [(0, 39, 'ITEM')]}),
('Buy any Moleskine Notebook or Accessory (excluding Planners) for $19.95 or more and get a FREE Moleskine Notebook Tool Belt value of $14.95.', {'entities': [(8, 26, 'ITEM'), (30, 39, 'ITEM'), (95, 113, 'ITEM')]}),
('$99.99 Member Only NOOK GlowLight Plus Offer', {'entities': [(19, 38, 'ITEM')]}),
('BN Classics Sale - Buy 2, Get the 3rd Free', {'entities': [(0, 11, 'ITEM')]}),
('Little Blue Truck\'s Halloween Only $7.99 with the Purchase of Any Kids\' Book', {'entities': [(0, 29, 'ITEM'), (66, 76, 'ITEM')]}),
('Exclusive Felt Tote Just $9.95 When You Buy Any Item', {'entities': [(10, 19, 'ITEM')]}),
('Get 1 Free Accessory with Tab 4 7" purchase', {'entities': [(11, 20, 'ITEM')]}),
('Save $5 on 2 Select Young Readers Books', {'entities': [(20, 39, 'ITEM')]}),
('Select Business Books - Buy 1, Get 1 at 50% Off', {'entities': [(7, 21, 'ITEM')]}),
('$5 Off One CD', {'entities': [(11, 13, 'ITEM')]}),
('$5 Off One Toy or Game Item (price $20+)', {'entities': [(11, 22, 'ITEM')]}),
('$8 Off One DVD or Blu-ray (price $40+)', {'entities': [(11, 25, 'ITEM')]}),
('$10 Off One Home & Gift Item', {'entities': [(12, 23, 'ITEM')]}),
('3 for $30: Select Paperbacks', {'entities': [(18, 28, 'ITEM')]}),
('10% Off Tech Toys for Educators', {'entities': [(8, 31, 'ITEM')]}),
('$5 Off Select Thrillers with Purchase of Girl on the Train', {'entities': [(14, 23, 'ITEM'), (41, 58, 'ITEM')]}),
('50% Off the list price of all eligible Dealmoon exclusive Offer items', {'entities': [(39, 47, 'ITEM')]}),
('Save $50 When You Buy a Teac Turntable and Teac Speakers', {'entities': [(24, 56, 'ITEM')]}),
('Buy 1, Get 1 50% Off Flameless Candles', {'entities': [(21, 38, 'ITEM')]}),
('$8 Off One DVD or Blu-ray (price $40+)', {'entities': [(11, 25, 'ITEM')]}),
('$5 Off One Toy or Game Item (price $20+)', {'entities': [(11, 22, 'ITEM')]}),
('$5 Off One CD', {'entities': [(11, 13, 'ITEM')]}),
('$10 Off One Home & Gift Item', {'entities': [(12, 23, 'ITEM')]}),
('Good Housekeeping Cookbook $9.99 Offer', {'entities': [(5, 26, 'ITEM')]}),
('20% Off print newsstand subscriptions', {'entities': [(14, 23, 'ITEM')]}),
('10% Off Tech Toys for Educators', {'entities': [(8, 31, 'ITEM')]}),
('Funko Pop Buy 2, Get 1 50% Off', {'entities': [(0, 9, 'ITEM')]}),
('Buy 1, Get 1 50% Art Supplies', {'entities': [(17, 29, 'ITEM')]}),
('Take 10% Off $35 to $74.99 HONEY', {'entities': [(27, 32, 'ITEM')]}),
('Take 10% Off $35 to $74.99 RMN', {'entities': [(27, 30, 'ITEM')]}),
('Take 10% Off $35 to $74.99 CABIN', {'entities': [(27, 32, 'ITEM')]}),
('Take 15% Off $75 to $124.99 HONEY', {'entities': [(28, 33, 'ITEM')]}),
('Take 15% Off $75 to $124.99 RMN', {'entities': [(28, 31, 'ITEM')]}),
('Take 15% Off $75 to $124.99 CABIN', {'entities': [(28, 33, 'ITEM')]}),
('Take 20% Off $125 or More HONEY', {'entities': [(26, 31, 'ITEM')]}),
('Take 20% Off $125 or More RMN', {'entities': [(26, 29, 'ITEM')]}),
('Take 20% Off $125 or More CABIN', {'entities': [(26, 31, 'ITEM')]}),
('Take 10% Off $35 to $74.99 RMN mobile', {'entities': [(27, 37, 'ITEM')]}),
('Take 15% Off $75 to $124.99 RMN mobile', {'entities': [(28, 38, 'ITEM')]}),
('10% Off Tech Toys for Educators', {'entities': [(8, 31, 'ITEM')]}),
('Save $5 on 2 Select Business Books', {'entities': [(20, 34, 'ITEM')]}),
('Select Paperbacks 3 for $30', {'entities': [(7, 17, 'ITEM')]}),
('Select Young Readers Books 2 for $20', {'entities': [(7, 26, 'ITEM')]}),
('15% Off Used Textbooks', {'entities': [(8, 22, 'ITEM')]}),
('Get $10 Off Every $100 You Spend on New & Used Textbooks', {'entities': [(36, 56, 'ITEM')]}),
('Buy 1, Get 1 50% Off Art Supplies', {'entities': [(21, 33, 'ITEM')]}),
('$5 Off One Toy or Game Item (price $20+)', {'entities': [(11, 22, 'ITEM')]}),
('$10 Off One Home & Gift Item', {'entities': [(12, 23, 'ITEM')]}),
('$5 Off Any DVD or Blu-ray Over $9.99', {'entities': [(11, 25, 'ITEM')]}),
('$5 Off One Vinyl LP', {'entities': [(11, 19, 'ITEM')]}),
('$15 Off Any Turntable', {'entities': [(12, 21, 'ITEM')]}),
('NOOK Samsung Upgrader Offer - Online', {'entities': [(0, 12, 'ITEM')]}),
('Select Hardcovers 2 for $30', {'entities': [(7, 17, 'ITEM')]}),
('$5 Off One Toy or Game Item (price $20+)', {'entities': [(11, 22, 'ITEM')]}),
('$5 Off Any Vinyl LP', {'entities': [(11, 19, 'ITEM')]}),
('$5 Off Any DVD or Blu-ray Over $9.99', {'entities': [(11, 25, 'ITEM')]}),
('$15 Off Any Turntable', {'entities': [(12, 21, 'ITEM')]}),
('$10 Off One Home & Gift Item', {'entities': [(12, 23, 'ITEM')]}),
('20% Off Print Newsstand', {'entities': [(14, 23, 'ITEM')]}),
('Select Paperbacks 3 for $30', {'entities': [(7, 17, 'ITEM')]}),
('$5 Off $50 or More, including new, used, and rental textbooks', {'entities': [(45, 61, 'ITEM')]}),
('Employee Appreciation Discount - 40% Off Physical Magazines', {'entities': [(41, 59, 'ITEM')]}),
('Employee Appreciation Discount - 40% Off Nook Accessories', {'entities': [(41, 57, 'ITEM')]}),
('Employee Appreciation Discount - 40% Off Books, Games and Gifts', {'entities': [(41, 46, 'ITEM'), (48, 54, 'ITEM')]}),
('Employee Appreciation Discount - 30% Off Music & Movies', {'entities': [(41, 55, 'ITEM')]}),
('$5 Off One Toy or Game Item (price $20+)', {'entities': [(11, 22, 'ITEM')]}),
('$5 Off Any Vinyl LP', {'entities': [(11, 19, 'ITEM')]}),
('$5 Off Any DVD or Blu-ray Over $9.99', {'entities': [(11, 25, 'ITEM')]}),
('$15 Off Any Turntable', {'entities': [(12, 21, 'ITEM')]}),
('$10 Off One Home & Gift Item', {'entities': [(12, 23, 'ITEM')]}),
('Free Baby BAGGU Bag with the purchase of Any Book', {'entities': [(5, 19, 'ITEM'), (45, 49, 'ITEM')]}),
('$5 Off $50 or More on New Used and Rental Textbooks', {'entities': [(22, 51, 'ITEM')]}),
('Select Young Readers Books - 2 for $20', {'entities': [(7, 26, 'ITEM')]}),
('10% Off Tech Toys for Educators', {'entities': [(8, 31, 'ITEM')]}),
('$10 Off One Home & Gift Item', {'entities': [(12, 23, 'ITEM')]}),
('$15 Off Any Turntable', {'entities': [(12, 21, 'ITEM')]}),
('$5 Off Any DVD or Blu-ray Over $9.99', {'entities': [(11, 25, 'ITEM')]}),
('$5 Off Any Vinyl LP', {'entities': [(11, 19, 'ITEM')]}),
('$5 Off One Toy or Game Item (price $20+)', {'entities': [(11, 22, 'ITEM')]}),
('15% Off Used Textbooks', {'entities': [(8, 22, 'ITEM')]}),
('$10 Off Every $100 You Spend on Textbooks Threshold 1', {'entities': [(32, 53, 'ITEM')]}),
('$10 Off Every $100 You Spend on Textbooks Threshold 2', {'entities': [(32, 53, 'ITEM')]}),
('$10 Off Every $100 You Spend on Textbooks Threshold 3', {'entities': [(32, 53, 'ITEM')]}),
('$10 Off Every $100 You Spend on Textbooks Threshold 4', {'entities': [(32, 53, 'ITEM')]}),
('$10 Off Every $100 You Spend on Textbooks Threshold 5', {'entities': [(32, 53, 'ITEM')]}),
('Buy Ship of the Dead, Get 1 Eligible Rick Riordan Title at 50% Off', {'entities': [(4, 20, 'ITEM'), (37, 55, 'ITEM')]}),
('Buy Turtles All the Way Down, get 1 eligible John Green title at 50% Off', {'entities': [(4, 28, 'ITEM'), (45, 61, 'ITEM')]}),
('Save $6 on Baby Driver DVD or Blu-ray and CD Purchase', {'entities': [(11, 44, 'ITEM')]}),
('Buy 3 Select Paperbacks for $30', {'entities': [(13, 23, 'ITEM')]}),
('Disney Classics 2 for $10', {'entities': [(0, 15, 'ITEM')]}),
('15% Off all KSNY Nook Accessories', {'entities': [(17, 33, 'ITEM')]}),
('$5 Off Every $50 Spent, Including Textbooks', {'entities': [(34, 43, 'ITEM')]}),
('Get $10 Off Every $100 You Spend on New & Used Textbooks', {'entities': [(36, 56, 'ITEM')]}),
('$30 Off a NOOK GlowLight Plus', {'entities': [(10, 29, 'ITEM')]}),
('Employee Appreciation Discount - 30% Off Music & Movies', {'entities': [(41, 55, 'ITEM')]}),
('Employee Appreciation Discount - 40% Off Books, Games and Gifts', {'entities': [(41, 46, 'ITEM'), (48, 54, 'ITEM')]}),
('Employee Appreciation Discount - 40% Off Nook Accessories', {'entities': [(41, 57, 'ITEM')]}),
('Employee Appreciation Discount - 40% Off Physical Magazines', {'entities': [(41, 59, 'ITEM')]}),
('40% Off One Eligible Coloring Book', {'entities': [(21, 34, 'ITEM')]}),
('Teen Paperbacks - Buy 2 Get the 3rd Free', {'entities': [(5, 15, 'ITEM')]}),
('20% Off One Manga Title', {'entities': [(12, 23, 'ITEM')]}),
('Coloring Book Offer: Buy 1, Get 1 50% Off With Single-Use Coupon', {'entities': [(0, 13, 'ITEM')]}),
('Buy "Where the Sidewalk Ends", Get a Select Collectible Edition for $5', {'entities': [(5, 28, 'ITEM'), (44, 63, 'ITEM')]}),
('I Need My Monster only $7.99 with the purchase of any kids\' book', {'entities': [(0, 17, 'ITEM'), (54, 64, 'ITEM')]}),
('Little Books to Build Big Libraries Buy 2 Get the 3rd Free', {'entities': [(0, 35, 'ITEM')]}),
('Junie B. Jones Buy 2 Get the 3rd Free', {'entities': [(0, 14, 'ITEM')]}),
('Illustrated Classics Buy 2 Get the 3rd Free', {'entities': [(0, 20, 'ITEM')]}),
('DC and Marvel Graphic Novels: Buy 2, Get the 3rd Free', {'entities': [(0, 28, 'ITEM')]}),
('If You Give A Mouse A Cookie Onl $7.99 with the purchase of Any Kids\' Book', {'entities': [(0, 28, 'ITEM'), (64, 74, 'ITEM')]}),
('Holiday Felt Tote Just $12.95 when you buy any item', {'entities': [(0, 17, 'ITEM')]}),
('Jingle Bells Christmas Carol Coloring Only $5 with the purchase of Any Coloring Book', {'entities': [(0, 37, 'ITEM'), (71, 84, 'ITEM')]}),
('30% Off the list price of one eligible cookbook', {'entities': [(39, 47, 'ITEM')]}),
('30% Off the list price of one eligible picture book', {'entities': [(39, 51, 'ITEM')]}),
('Dr. Seuss Buy 2 Get the 3rd Free', {'entities': [(0, 9, 'ITEM')]}),
('Little Golden Books Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('Employee Appreciation Discount - 40% Off Books, Games and Gifts', {'entities': [(41, 46, 'ITEM'), (48, 54, 'ITEM')]}),
('Employee Appreciation Discount - 30% Off Music & Movies', {'entities': [(41, 55, 'ITEM')]}),
('Employee Appreciation Discount - 40% Off Nook Accessories', {'entities': [(41, 57, 'ITEM')]}),
('Employee Appreciation Discount - 40% Off Physical Magazines', {'entities': [(41, 59, 'ITEM')]}),
('Classic Starts Buy 2 Get the 3rd Free', {'entities': [(0, 14, 'ITEM')]}),
('I Survived Series - Buy 2, Get the 3rd Free', {'entities': [(0, 17, 'ITEM')]}),
('LEGO Duplo & LEGO Junior: Buy 1, Get 1 50% Off', {'entities': [(0, 10, 'ITEM')]}),
('Magic Tree House Buy 2 Get the 3rd Free', {'entities': [(0, 16, 'ITEM')]}),
('Must-Read Paperbacks: Buy 2 Get the 3rd Free', {'entities': [(10, 20, 'ITEM')]}),
('Beginning Readers Buy 2 Get the 3rd Free', {'entities': [(0, 17, 'ITEM')]}),
('Buy 1, Get 1 50% Off Art Supplies', {'entities': [(21, 33, 'ITEM')]}),
('Buy 1, Get 1 50% Off Select Games & Puzzles', {'entities': [(28, 34, 'ITEM'), (36, 43, 'ITEM')]}),
('Black Friday Buy 1, Get 1 50% Off Toys & Games', {'entities': [(34, 46, 'ITEM')]}),
('Get Barnsie for only $9.95 When you buy any item', {'entities': [(4, 11, 'ITEM')]}),
('Battat: Buy 1 Get 1 50% pff', {'entities': [(0, 6, 'ITEM')]}),
('Manga Mania Sale - Buy 2, Get the 3rd Free', {'entities': [(0, 12, 'ITEM')]}),
('Melissa & Doug: Buy 1 Get 1 50% Off', {'entities': [(0, 14, 'ITEM')]}),
('US Playing Cards: Buy 1 Get 1 50% Off', {'entities': [(0, 16, 'ITEM')]}),
('Buy 1, Get 1 50% Off Flameless Candles', {'entities': [(21, 38, 'ITEM')]}),
('Buy any two select Bookshots titles for $5.99', {'entities': [(19, 35, 'ITEM')]}),
('B&N Classics: Buy 2, get the 3rd Free', {'entities': [(0, 12, 'ITEM')]}),
('Puzzles: Buy 1, Get 1 50% Off', {'entities': [(0, 7, 'ITEM')]}),
('Buy 1 Get 1 Free on Select DVDs and Blu-rays', {'entities': [(27, 31, 'ITEM'), (36, 44, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('Image Comics: Buy 2, Get the 3rd Free', {'entities': [(0, 12, 'ITEM')]}),
('Velveteen Rabbit 50% Off When You Buy Any Item', {'entities': [(0, 16, 'ITEM')]}),
('Little Big Books to Build Big Libraries Buy 2 Get the 3rd Free', {'entities': [(0, 39, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('Spring tote just $12.95 when you buy any item', {'entities': [(0, 11, 'ITEM')]}),
('10% Off of the NOOK Tablet 7"', {'entities': [(15, 29, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('30% Off Any Collectible Edition', {'entities': [(12, 31, 'ITEM')]}),
('30% Off one T&G Collectible', {'entities': [(12, 27, 'ITEM')]}),
('Little Books to Build Big Libraries Buy 1 Get 1 50% Off', {'entities': [(0, 35, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('The Rainbow Fish Only $7.99 with the Purchase of any kids\' book', {'entities': [(0, 16, 'ITEM'), (53, 63, 'ITEM')]}),
('20% Off Any One Mystery', {'entities': [(16, 23, 'ITEM')]}),
('20% Off Any One Teen Book', {'entities': [(16, 25, 'ITEM')]}),
('DC Graphic Novels - Buy 2, Get the 3rd Free', {'entities': [(0, 17, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('Manga Mania Sale - Buy 2, Get the 3rd Free', {'entities': [(0, 12, 'ITEM')]}),
('Little Books to Build Big Libraries - Buy 1, Get 1 50% Off', {'entities': [(0, 35, 'ITEM')]}),
('Funko Pop Buy 1 Get 1 30% Off', {'entities': [(0, 9, 'ITEM')]}),
('Paperback Favorites - Buy 2, Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('Marvel Graphic Novels - Buy 2, Get the 3rd Free', {'entities': [(0, 21, 'ITEM')]}),
('Little Books to Build Big Libraries Buy 2 Get the 3rd Free', {'entities': [(0, 35, 'ITEM')]}),
('DC Graphic Novels - Buy 2, Get the 3rd Free', {'entities': [(0, 17, 'ITEM')]}),
('20% Off Any One Mystery', {'entities': [(16, 23, 'ITEM')]}),
('20% Off Any One Teen Book', {'entities': [(16, 25, 'ITEM')]}),
('Little Books to Build Big Libraries Buy 2 Get the 3rd Free', {'entities': [(0, 35, 'ITEM')]}),
('FREE Who Was? Book of Fun When You Buy Any 2 Who Was? What Was? Where Is? Series Books for Kids', {'entities': [(14, 18, 'ITEM'), (81, 95, 'ITEM')]}),
('DC Graphic Novels - Buy 2, Get the 3rd Free', {'entities': [(0, 17, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('Jigsaw Puzzles: Buy 1, Get 1 50% Off', {'entities': [(0, 14, 'ITEM')]}),
('20% Off Any One Cookbook', {'entities': [(16, 24, 'ITEM')]}),
('20% Off Any One Mystery', {'entities': [(16, 23, 'ITEM')]}),
('$10 Off any Whole Cheesecake', {'entities': [(18, 28, 'ITEM')]}),
('20% Off 1 Picture Book', {'entities': [(10, 22, 'ITEM')]}),
('Get Barnsie or Noble for only $9.95 each with purchase', {'entities': [(4, 11, 'ITEM'), (15, 20, 'ITEM')]}),
('DC and Marvel Graphic Novels: Buy 2, Get the 3rd Free', {'entities': [(0, 28, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('A Loud Winter\'s Nap Only $7.99 with the purchase of any Kid\'s book', {'entities': [(2, 19, 'ITEM'), (56, 66, 'ITEM')]}),
('Beginning Readers Buy 2 Get the 3rd Free', {'entities': [(0, 17, 'ITEM')]}),
('Dr. Seuss Buy 2 Get the 3rd Free', {'entities': [(0, 9, 'ITEM')]}),
('Little Golden Books Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('20% Off One History Book (Trade, excludes Bargain)', {'entities': [(12, 24, 'ITEM')]}),
('Buy 1 Get 1 50% Off Battat', {'entities': [(20, 26, 'ITEM')]}),
('Buy 1 Get 1 50% Off Melissa & Doug', {'entities': [(20, 34, 'ITEM')]}),
('Funko Pop Buy 1 Get 1 50% Off', {'entities': [(0, 9, 'ITEM')]}),
('Buy 1, Get 1 50% Off Toys & Games', {'entities': [(21, 25, 'ITEM')]}),
('You! Only $7.99 with the Purchase of Any Kids Book', {'entities': [(0, 4, 'ITEM'), (41, 50, 'ITEM')]}),
('A Series of Unfortunate Events The Bad Beginning Only $4.99 with the Purchase of Any Kids\' Book', {'entities': [(0, 48, 'ITEM'), (85, 95, 'ITEM')]}),
('Purchase Taylor Swift Exclusive Vinyl and Save 30% Off Any One Crosley Turntable', {'entities': [(9, 37, 'ITEM'), (71, 80, 'ITEM')]}),
('Buy One, Get One Free - Select DVDs & Blu-rays', {'entities': [(31, 35, 'ITEM'), (38, 46, 'ITEM')]}),
('Buy any 2 qualifying books and get a third book for free.', {'entities': [(21, 25, 'ITEM'), (43, 47, 'ITEM')]}),
('Buy 3 select paperbacks for $30', {'entities': [(13, 23, 'ITEM')]}),
('Favorite Paperbacks Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]}),
('20% Off Any One Chapter Book', {'entities': [(24, 28, 'ITEM')]}),
('20% Off Any One Mystery', {'entities': [(16, 23, 'ITEM')]}),
('Mother Bruce Only $7.99 with the Purchase of Any Kids\' Book', {'entities': [(0, 12, 'ITEM'), (49, 59, 'ITEM')]}),
('Board Books Buy 2 Get the 3rd Free', {'entities': [(0, 11, 'ITEM')]}),
('Buy 2 Get the 3rd Free on kid books', {'entities': [(0, 11, 'ITEM')]}),
('Buy any jigsaw puzzle and get a 2nd puzzle at 50% Off', {'entities': [(8, 21, 'ITEM'), (36, 42, 'ITEM')]}),
('Cyber Monday T&G 30% Off List Price of one Item', {'entities': [(13, 16, 'ITEM')]}),
('FREE Snapcase Solo with Purchase of Lightblock', {'entities': [(5, 18, 'ITEM'), (36, 46, 'ITEM')]}),
('Get a Peter Rabbit Plush for only $6.95 with the purchase of any item.  List Price $12.95. While Supplies Last.', {'entities': [(6, 18, 'ITEM')]}),
('Get 1 Free Accessory with Tab 4 7" purchase', {'entities': [(11, 20, 'ITEM'), (26, 34, 'ITEM')]}),
('10% Off Your Entire Purchase', {'entities': []}),
('Spend $20, Get 20% Off Your Entire Purchase', {'entities': []}),
('20% Off Any Eligible Item Plus Free Express Shipping', {'entities': []}),
('Tier Offer 1', {'entities': []}),
('Take 15% Off orders of $50 or More DEALSPLUS', {'entities': []}),
('10% Off Entire Order Tax Day Pocket Points', {'entities': []}),
('$20 Off Your Entire Purchase of $50 or More', {'entities': []}),
('Enjoy Free Shipping on All Orders APO/FRP/AK/HI', {'entities': []}),
('10%/$35, 15%/$60, 20%/$100 or More Pocket Points', {'entities': []}),
('Get $5 Off $35 or More (Affiliate)', {'entities': []}),
('Take 10% Off $35 to $59.99 Accountless', {'entities': []}),            
('Above & Beyond Customer Service Winners', {'entities': []}),
('Free Standard Shipping', {'entities': []}),
('Veteran\'s Day 20% Off Select NOOKS', {'entities': [(29, 34,'ITEM')]}),            
('Summer Stripe Canvas Tote Just $5.00 when you buy any 3 books', {'entities': [(7, 25, 'ITEM'), (56, 61, 'ITEM')]}),
('Free Soup and Sandwich Purchases', {'entities': [(5, 9, 'ITEM'), (14, 22, 'ITEM')]}),
('BN College Free Membership', {'entities': []}),
('Buy 2 Pete the Cat books for $20', {'entities': [(6, 24, 'ITEM')]}),
('Get 2 Packets of Individually Wrapped Dessert Truffles for $15', {'entities': [(38, 53, 'ITEM')]}),
('Member Double Discount NOOK GlowLight 3', {'entities': [(23, 39, 'ITEM')]}),
('Select Elephant and Piggie Books - Buy 1, get 1 50% Off', {'entities': [(7, 32, 'ITEM')]}),
('Free Soup with Sandwich Purchase', {'entities': [(5, 9, 'ITEM'), (15, 23, 'ITEM')]}),     
('Favorite Paperbacks: Buy 2 Get the 3rd Free', {'entities': [(0, 19, 'ITEM')]})]

# %%
from spacy.gold import GoldParse
from spacy import displacy

# %%
import os
os.chdir('C:\\Users\\user\\Desktop\\model')
output_dir=os.getcwd()
output_dir
# Out:
# 'C:\\Users\\user\\Desktop\\model'

# %%
# ent = "teen books"
# reg_exp = r'\b' +ent + r'?\b'
# print(reg_exp)
# regex = re.compile(reg_exp, re.IGNORECASE)
# st = "20% off on teen book till 2pm."
# for i in regex.finditer(st):
#     print ("('"+st+"', {'entities': [("+str(i.start())+", "+str(i.end())+", 'ITEM')]}),")

# %%
LABEL='ITEM'
@plac.annotations(
    model=("Model name. Defaults to blank 'en' model.", "option", "m", str),
    new_model_name=("New model name for model meta.", "option", "nm", str),
    output_dir=("Optional output directory", "option", "o", Path),
    n_iter=("Number of training iterations", "option", "n", int))
def main(model=None, new_model_name='item', output_dir=None, n_iter=10):
    """Set up the pipeline and entity recognizer, and train the new entity."""
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank('en')  # create blank Language class
        print("Created blank 'en' model")
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner)
    # otherwise, get it, so we can add labels to it
    else:
        ner = nlp.get_pipe('ner')

    ner.add_label(LABEL)   # add new entity label to entity recognizer
    if model is None:
        optimizer = nlp.begin_training()
    else:
        # Note that 'begin_training' initializes the models, so it'll zero out
        # existing entity types.
        optimizer = nlp.entity.create_optimizer()



    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update([text], [annotations], sgd=optimizer, drop=0.35,losses=losses)
            print(losses)

    # test the trained model
    test_text = 'Jingle Bells Christmas Carol Coloring Only $5 with the purchase of Any Coloring Book'
    doc = nlp(test_text)
    print("Entities in '%s'" % test_text)
    for ent in doc.ents:
        print(ent.label_, ent.text)

#     if output_dir is not None:
#         output_dir = Path(output_dir)
#         if not output_dir.exists():
#             output_dir.mkdir()
    #nlp.meta['name'] = new_model_name  # rename model
    import os
#     os.mkdir('C:\\Users\\user\\Desktop\\model1')
    nlp.to_disk('C:\\Users\\user\\Desktop\\model1')
    print("Saved model to", output_dir)
    print(output_dir)
#         test the saved model
main()
# Out:
# Created blank 'en' model
# ...
# {'ner': 921.8747688691664}
# {'ner': 488.0171183216366}
# {'ner': 344.35684583057963}
# {'ner': 261.2094200302055}
# {'ner': 177.7284209846396}
# {'ner': 113.58173768609805}
# {'ner': 114.57858479636612}
# {'ner': 117.2926100691718}
# {'ner': 103.27851542532557}
# {'ner': 83.38644785221459}
# Entities in 'Jingle Bells Christmas Carol Coloring Only $5 with the purchase of Any Coloring Book'
# ITEM Jingle Bells Christmas Carol Coloring
# ITEM Coloring Book
# Saved model to None
# None

# %%
import spacy
test_text='Free Soup with Sandwich Purchase'
nlp = spacy.load('C:\\Users\\user\\Desktop\\model1')
doc2 = nlp(test_text)
for ent in doc2.ents:
    print(ent.label_, ent.text)
# Out:
# ITEM Soup

# %%
## promos having no items 
count =0
for index,row in test.iterrows():
    if len(row['items'])==0:
        print (test['Promotion_Description'][index])
# Out:
# Get $5 Off $50 or more
# $10 Off Purchase of $50 or More
# Get $5 Off $50 or more
# 10% Off Your Order
# Get $5 Off $50 or more
# 10% Off every elible Item
# Get $5 Off $50 or more
# Get $5 Off $50 or more
# 10% Off Your Order - Store
# Get $5 Off $50 or more
# Get $5 Off $50 or more
# Get $5 Off $50 or more
# 10% Off One Item
# 20% Off Everything if You Spend $50
# 10% Off Everything if You Spend $40
# 15% Off $40 or More
# Get $10 Off $75 or more
# Get $10 Off $75 or more
# Get $10 Off $75 or more
# $10 Off Purchase of $100 or More
# Get 10% Off $50 or more
# $10 Off Purchase of $100 or More
# $10 Off Purchase of $100 or More
# $5 Off Purchase of $50 or More
# Get $10 Off $75 or more
# Get $10 Off $75 or more
# Get 10% Off $50 or more
# Get 20% Off $50 or more
# Tier Offer 1
# Tier Offer 2
# Tier Offer 3
# Get 20% Off $60 or more
# Get 25% Off $100 or more
# Get 24% Off Your Entire Order
# Tier Offer 1
# Tier Offer 2
# Tier Offer 3
# $10 Off Purchase of $100 or More
# ...
